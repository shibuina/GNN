# %%
import pandas as pd
df = pd.read_csv('movielens_1m_data.csv')

# %%
df['rating'] = df['rating'].astype(float)
# df.notnull()
df.dropna(inplace=True)

# %%
df
# Out:
#         userId movieId  rating
# 0            1   a1193     5.0
# 1            1    a661     3.0
# 2            1    a914     3.0
# 3            1   a3408     4.0
# 4            1   a2355     5.0
# ...        ...     ...     ...
# 872946    5271   a2872     3.0
# 872947    5271    a605     2.0
# 872948    5271    a608     5.0
# 872949    5271   a1147     5.0
# 872950    5271   a1148     5.0
#
# [872951 rows x 3 columns]

# %%
df.to_csv('movielens_1m.csv')
